# %% [markdown]
# # 03 - Dataset tabular para olas de calor
#
# Genera train/test con lags optimos por correlacion espacial.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_DIR = PROJECT_ROOT / "data" / "datos_tfg"
DATA_DIR

# %%
from src.modeling.dataset_preparation import (
    generar_dataset_final_ml_limpio_v3,
    separar_X_y,
)

# %%
RUTA_X_OLAS = "train/X_olas_calor_final.nc"

df_train, df_test, features, scaler = generar_dataset_final_ml_limpio_v3(
    ruta_nc=RUTA_X_OLAS,
    var_target="mx2t",
    p_umbral=0.95,
    max_lags=30,
    dias_test=365,
)

X_train, y_train, X_test, y_test = separar_X_y(df_train, df_test, features)
df_train.shape, df_test.shape, len(features)

# %%
features
