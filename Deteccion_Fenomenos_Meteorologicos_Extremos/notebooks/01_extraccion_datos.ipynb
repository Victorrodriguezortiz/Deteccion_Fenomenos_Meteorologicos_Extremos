# %% [markdown]
# # 01 - Extraccion de datos
#
# Notebook base para lanzar descargas desde el pipeline de extraccion.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_DIR = PROJECT_ROOT / "data" / "datos_tfg"
SCRIPT_EXTRACCION = PROJECT_ROOT / "src" / "extraccion" / "extraccion_datos_pipeline.py"

PROJECT_ROOT, DATA_DIR, SCRIPT_EXTRACCION

# %% [markdown]
# ## Ejemplos de ejecucion
#
# Descomenta la llamada que quieras lanzar.

# %%
# Ayuda del script
# !python {SCRIPT_EXTRACCION} --help

# Olas de calor, un ano concreto
# !python {SCRIPT_EXTRACCION} --producto olas_calor --years 2025

# Sentinel-5P solo NO2
# !python {SCRIPT_EXTRACCION} --producto sentinel5p --s5p-producto NO2 --years 2025

# Todo el flujo de extraccion configurado
# !python {SCRIPT_EXTRACCION} --producto todo --years 2020 2021 2022 2023 2024 2025
