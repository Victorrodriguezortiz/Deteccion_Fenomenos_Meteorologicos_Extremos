# %% [markdown]
# # 07 - Explicabilidad y mapas
#
# SHAP y matrices de confusion espacial.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

from src.modeling.graphs import (
    plot_mapa_confusion_evento,
    plot_mapa_confusion_eventos_rango,
    plot_panel_mapa_confusion_eventos_rango,
    restaurar_lat_lon_desde_scaler,
)

from src.modeling.ingenieria_variables_precipitaciones import (
    calcular_shap_lstm_atencion,
    plot_shap_lstm_resumen,
    plot_shap_lstm_temporal,
)

# %% [markdown]
# ## Matriz de confusion espacial
#
# El DataFrame debe tener: `time`, `lat`, `lon`, `y_real`, `y_pred`.

# %%
# df_evento = pd.DataFrame(...)

# resumen_panel = plot_panel_mapa_confusion_eventos_rango(
#     df_evento=df_evento,
#     fecha_inicio="2025-08-03",
#     fecha_fin="2025-08-18",
#     mostrar_tn=True,
#     ncols=4,
#     figsize=(18, 14),
#     extent=(-10, 4, 35, 44.5),
#     pintar_mapa=True,
#     guardar=False,
# )

# resumen_panel

# %% [markdown]
# ## SHAP para LSTM

# %%
# shap_result = calcular_shap_lstm_atencion(
#     modelo=resultado_lstm["model"],
#     X_train=dataset_seq["X_train"],
#     X_test=dataset_seq["X_test"],
#     features=dataset_seq["features"],
#     background_size=100,
#     explain_size=200,
# )

# plot_shap_lstm_resumen(shap_result, top_n=20)
# plot_shap_lstm_temporal(shap_result)
