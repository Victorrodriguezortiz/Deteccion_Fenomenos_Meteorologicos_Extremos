# %% [markdown]
# # 02 - Limpieza y procesado
#
# Notebook para limpiar productos satelitales y generar archivos procesados.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_DIR = PROJECT_ROOT / "data" / "datos_tfg"
DATA_DIR

# %%
from src.limpieza.data_processing import (
    procesar_producto_satelital_limpio,
    procesar_satelites_calidad_aire,
    limpieza_xarray_lst_celsius_solo_superficie_lst,
    procesar_calidad_aire_diario_final_v4,
    procesar_nasa_gpm_mensual,
    crear_dataset_X_olas_calor_final,
    crear_dataset_X_precipitaciones_extremas,
    construir_cubo_entrenamiento,
)

# %% [markdown]
# ## Limpieza de satelites de calidad del aire
#
# Cada producto queda separado.

# %%
# procesar_producto_satelital_limpio("no2")
# procesar_producto_satelital_limpio("co")
# procesar_producto_satelital_limpio("aerosoles")
# procesar_producto_satelital_limpio("aod")

# O todos:
# resultados = procesar_satelites_calidad_aire()

# %% [markdown]
# ## Limpieza LST Sentinel-3

# %%
# lst_limpia = limpieza_xarray_lst_celsius_solo_superficie_lst()

# %% [markdown]
# ## Cubos finales
#
# Ajusta las rutas segun los archivos limpios disponibles.

# %%
rutas_olas = {
    # "cams": "dataset_final_limpio/cams_diario_limpio.nc",
    # "s3lst": "dataset_final_limpio/lst_final_limpio_celsius_mascara_lst.nc",
    # "era5": "dataset_final_limpio/olas_calor_diario.nc",
}

# ds_X_olas = crear_dataset_X_olas_calor_final(
#     rutas_procesadas=rutas_olas,
#     ruta_salida="train/X_olas_calor_final.nc",
# )
