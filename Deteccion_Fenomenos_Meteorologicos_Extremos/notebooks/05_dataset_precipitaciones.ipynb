# %% [markdown]
# # 05 - Dataset para precipitaciones extremas
#
# Preparacion tabular fuerte y preparacion secuencial LSTM/atencion.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_DIR = PROJECT_ROOT / "data" / "datos_tfg"
DATA_DIR

# %%
from src.modeling.ingenieria_variables_precipitaciones import (
    preparar_experimento_horario_precipitacion,
    crear_dataset_secuencial_precipitacion,
)

# %% [markdown]
# ## Dataset tabular con ingenieria fuerte

# %%
# experimento_h24 = preparar_experimento_horario_precipitacion(
#     ruta_nc=DATA_DIR / "train_precipitaciones_horario" / "X_train_precipitaciones_horario.nc",
#     var_prec="tp_mm",
#     horizonte=24,
#     umbral=4.0,
#     max_rows=300_000,
#     neg_por_pos=8,
#     top_k_mrmr=70,
#     n_features_rfe=35,
#     dias_test=365,
# )

# experimento_h24.keys()

# %% [markdown]
# ## Dataset secuencial: evento entre 24h y 48h

# %%
dataset_seq_24_48 = crear_dataset_secuencial_precipitacion(
    ruta_nc=DATA_DIR / "train_precipitaciones_horario" / "X_train_precipitaciones_horario.nc",
    var_prec="tp_mm",
    horizonte=24,
    horizonte_inicio=24,
    horizonte_fin=48,
    umbral=4.0,
    seq_len=72,
    max_samples=80_000,
    positive_ratio=0.20,
    dias_test=365,
    random_state=42,
    incluir_derivadas=True,
)

dataset_seq_24_48["X_train"].shape, dataset_seq_24_48["X_test"].shape, dataset_seq_24_48["features"]
